# %% [markdown]
# # Linear algebra refresher — practice
#
# Follow along with [`../lessons/08-linear-algebra.md`](../lessons/08-linear-algebra.md). Type the commands yourself; don't paste.

# %%
import numpy as np

# %% [markdown]
# ## Vector operations

# %% [markdown]
# ## Multiplication

# %% [markdown]
# ## Identity matrix

# %% [markdown]
# ## Inverse
