# %% [markdown]
# # Pandas — practice
#
# Follow along with [`../lessons/09-pandas.md`](../lessons/09-pandas.md). Type the commands yourself; don't paste.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## DataFrames

# %% [markdown]
# ## Series

# %% [markdown]
# ## Index

# %% [markdown]
# ## Element-wise operations

# %% [markdown]
# ## Filtering

# %% [markdown]
# ## String operations

# %% [markdown]
# ## Summarizing operations

# %% [markdown]
# ## Missing values

# %% [markdown]
# ## Grouping

# %% [markdown]
# ## Getting the NumPy arrays
